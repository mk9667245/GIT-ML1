# %% [markdown]
# # Text

# %%
1+2
# Out:
# 3

# %% [markdown]
# # 导入依赖包

# %%
import numpy as np#处理矩阵
import pandas as pd#numpy 加强版，并且可以帮我们读写数据文件
import matplotlib.pylab as plt#帮助我们数据可视化

# %% [markdown]
# # 不要管我

# %% [markdown]
# # 导入数据

# %%
dataset=pd.read_csv('Salary_Data.csv')
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# # 数据预处理

# %%
x=dataset.iloc[:,:-1].values#工作了几年
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y=dataset.iloc[:,1].values#工作了几年对应的薪资
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %% [markdown]
# # 数据分割

# %%
from sklearn.model_selection import train_test_split#拿一把刀

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 1 / 3, random_state = 0)
x_test
# Out:
# array([[ 1.5],
#        [10.3],
#        [ 4.1],
#        [ 3.9],
#        [ 9.5],
#        [ 8.7],
#        [ 9.6],
#        [ 4. ],
#        [ 5.3],
#        [ 7.9]])

# %% [markdown]
# # 建立模型

# %%
from sklearn.linear_model import LinearRegression#调用线性回归模型

# %%
regressor = LinearRegression()#把包拿来用 用来做模型
regressor.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# # 作出预测

# %%
y_pred=regressor.predict(5)
print("5年工作经验的薪资：",y_pred)
print(dataset)
# Out:
# 5年工作经验的薪资： [73545.90445964]
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %% [markdown]
# # 数据可视化

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Salary vs Years')
plt.xlabel('Years')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Salary vs Years')
plt.xlabel('Years')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # 分类

# %% [markdown]
# # 引入需要的依赖包

# %% [markdown]
# 读取数据

# %%
import numpy as np#处理矩阵
import pandas as pd#numpy 加强版，并且可以帮我们读写数据文件
import matplotlib.pylab as plt#帮助我们数据可视化

# %% [markdown]
# # 读取数据

# %%
dataset=pd.read_csv('Social_Network_Ads.csv')
dataset
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# 5    15728773    Male  27.0          58000.0          0
# 6    15598044  Female  27.0          84000.0          0
# 7    15694829  Female  32.0         150000.0          1
# 8    15600575    Male  25.0          33000.0          0
# 9    15727311  Female  35.0          65000.0          0
# 10   15570769  Female  26.0          80000.0          0
# 11   15606274  Female  26.0          52000.0          0
# 12   15746139    Male  20.0          86000.0          0
# 13   15704987    Male  32.0          18000.0          0
# 14   15628972    Male  18.0          82000.0          0
# 15   15697686    Male  29.0          80000.0          0
# ...

# %%
x=dataset.iloc[:,[2,3]].values#取出年龄跟性别
x#他们之间差了1000倍，这样会引起误差
# Out:
# array([[1.90e+01, 1.90e+04],
#        [3.50e+01, 2.00e+04],
#        [2.60e+01, 4.30e+04],
#        [2.70e+01, 5.70e+04],
#        [1.90e+01, 7.60e+04],
#        [2.70e+01, 5.80e+04],
#        [2.70e+01, 8.40e+04],
#        [3.20e+01, 1.50e+05],
#        [2.50e+01, 3.30e+04],
#        [3.50e+01, 6.50e+04],
#        [2.60e+01, 8.00e+04],
#        [2.60e+01, 5.20e+04],
#        [2.00e+01, 8.60e+04],
#        [3.20e+01, 1.80e+04],
#        [1.80e+01, 8.20e+04],
#        [2.90e+01, 8.00e+04],
#        [4.70e+01, 2.50e+04],
#        [4.50e+01, 2.60e+04],
#        [4.60e+01, 2.80e+04],
#        [4.80e+01, 2.90e+04],
#        [4.50e+01, 2.20e+04],
#        [4.70e+01, 4.90e+04],
#        [4.80e+01, 4.10e+04],
#        [4.50e+01, 2.20e+04],
#        [4.60e+01, 2.30e+04],
#        [4.70e+01, 2.00e+04],
#        [4.90e+01, 2.80e+04],
#        [4.70e+01, 3.00e+04],
#        [2.90e+01, 4.30e+04],
#        [3.10e+01, 1.80e+04],
#        [3.10e+01, 7.40e+04],
#        [2.70e+01, 1.37e+05],
# ...

# %%
y = dataset.iloc[:, -1].values#最后一列

# %% [markdown]
# # 数据预处理

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state = 0)#分割测试最理想比例，0.2~0.25

# %% [markdown]
# # 数据标准化

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc_x=StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)
x_train
# Out:
# array([[ 0.58164944, -0.88670699],
#        [-0.60673761,  1.46173768],
#        [-0.01254409, -0.5677824 ],
#        [-0.60673761,  1.89663484],
#        [ 1.37390747, -1.40858358],
#        [ 1.47293972,  0.99784738],
#        [ 0.08648817, -0.79972756],
#        [-0.01254409, -0.24885782],
#        [-0.21060859, -0.5677824 ],
#        [-0.21060859, -0.19087153],
#        [-0.30964085, -1.29261101],
#        [-0.30964085, -0.5677824 ],
#        [ 0.38358493,  0.09905991],
#        [ 0.8787462 , -0.59677555],
#        [ 2.06713324, -1.17663843],
#        [ 1.07681071, -0.13288524],
#        [ 0.68068169,  1.78066227],
#        [-0.70576986,  0.56295021],
#        [ 0.77971394,  0.35999821],
#        [ 0.8787462 , -0.53878926],
#        [-1.20093113, -1.58254245],
#        [ 2.1661655 ,  0.93986109],
#        [-0.01254409,  1.22979253],
#        [ 0.18552042,  1.08482681],
#        [ 0.38358493, -0.48080297],
#        [-0.30964085, -0.30684411],
#        [ 0.97777845, -0.8287207 ],
# ...

# %% [markdown]
# # 建立分类模型

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# # 做出预测

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[65,  3],
#        [ 8, 24]], dtype=int64)

# %%
from matplotlib.colors import ListedColormap
x_set, y_set = x_train, y_train
X1, X2 = np.meshgrid(np.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],
                c = ListedColormap(('orange', 'blue'))(i), label = j)
plt.title('Classifier (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()

# %%
# Visualising the Test set results
from matplotlib.colors import ListedColormap
x_set, y_set = x_test, y_test
X1, X2 = np.meshgrid(np.arange(start = x_set[:, 0].min() - 1, stop = x_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = x_set[:, 1].min() - 1, stop = x_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1],
                c = ListedColormap(('orange', 'blue'))(i), label = j)
plt.title('Classifier (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
